# %%
def salary_checker(x):
    if x>50000:
        return "High"
    else:
        return "Low"

# %%
'6-7-8'.split('-')
# Out:
# ['6', '7', '8']

# %%
f,i=map(int,['6','7'])
print(f,i)
# Out:
# 6 7

# %%
def cvt(x):
   f,i=map(int,x.split('-'))
   return f+i/12

# %%
cvt('6-7')
# Out:
# 6.583333333333333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
df.shape
# Out:
# (458, 9)

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)    148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
# ...

# %%
df=pd.read_csv('nba (1).csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('nba (1).csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df['Height']
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# 457     NaN
# Name: Height, Length: 458, dtype: object

# %%
df['Height']=df['Height'].apply(cvt)

# %%
df
# Out:
#               Name            Team  Number Position   Age    Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0  6.166667   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0  6.500000   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0  6.416667   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0  6.666667   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0  7.000000   238.0
# ..             ...             ...     ...      ...   ...       ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0  6.666667   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0  6.500000   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0  6.833333   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0  6.250000   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0  7.000000   231.0
#
#            College     Salary
# ...

# %%
df['Height'].mean()
# Out:
# np.float64(6.572344322344323)

# %%
df.groupby('Team')['Height'].agg(lambda x:x.max()-x.min())
# Out:
# Team
# Atlanta Hawks             0.750000
# Boston Celtics            1.250000
# Brooklyn Nets             1.083333
# Charlotte Hornets         1.000000
# Chicago Bulls             0.916667
# Cleveland Cavaliers       0.833333
# Dallas Mavericks          1.000000
# Denver Nuggets            0.750000
# Detroit Pistons           0.666667
# Golden State Warriors     0.750000
# Houston Rockets           0.750000
# Indiana Pacers            1.000000
# Los Angeles Clippers      0.916667
# Los Angeles Lakers        0.750000
# Memphis Grizzlies         0.750000
# Miami Heat                0.666667
# Milwaukee Bucks           0.666667
# Minnesota Timberwolves    0.833333
# New Orleans Pelicans      0.750000
# New York Knicks           0.833333
# Oklahoma City Thunder     0.750000
# Orlando Magic             0.916667
# Philadelphia 76ers        1.000000
# Phoenix Suns              1.166667
# Portland Trail Blazers    1.000000
# Sacramento Kings          1.000000
# ...

# %%
m=df['Salary'].mean()
s=df['Salary'].std()

# %%
def norm(x):
    return (x-m)/s

# %%
df['Salary'].apply(norm)
# Out:
# 0      0.607461
# 1      0.424986
# 3     -0.678098
# 6     -0.673739
# 7     -0.479548
#          ...
# 449   -0.639073
# 451   -0.710774
# 452   -0.464969
# 453   -0.427168
# 456   -0.717430
# Name: Salary, Length: 364, dtype: float64

# %%
df['Salary'].apply(norm)
# Out:
# 0      0.607461
# 1      0.424986
# 3     -0.678098
# 6     -0.673739
# 7     -0.479548
#          ...
# 449   -0.639073
# 451   -0.710774
# 452   -0.464969
# 453   -0.427168
# 456   -0.717430
# Name: Salary, Length: 364, dtype: float64

# %%
df.groupby('Position')['Salary'].transform(lambda x:(x-x.mean())/x.std())
# Out:
# 0      0.557960
# 1      0.403940
# 3     -0.595804
# 6     -0.660023
# 7     -0.621956
#          ...
# 449   -0.552333
# 451   -0.663602
# 452   -0.445534
# 453   -0.492230
# 456   -0.832440
# Name: Salary, Length: 364, dtype: float64

# %%
df.groupby('Team')['Salary'].mean()<5000000
# Out:
# Team
# Atlanta Hawks             False
# Boston Celtics             True
# Brooklyn Nets              True
# Charlotte Hornets          True
# Chicago Bulls             False
# Cleveland Cavaliers       False
# Dallas Mavericks           True
# Denver Nuggets             True
# Detroit Pistons            True
# Golden State Warriors     False
# Houston Rockets            True
# Indiana Pacers             True
# Los Angeles Clippers      False
# Los Angeles Lakers         True
# Memphis Grizzlies          True
# Miami Heat                False
# Milwaukee Bucks            True
# Minnesota Timberwolves     True
# New Orleans Pelicans       True
# New York Knicks           False
# Oklahoma City Thunder     False
# Orlando Magic              True
# Philadelphia 76ers         True
# Phoenix Suns               True
# Portland Trail Blazers     True
# Sacramento Kings           True
# San Antonio Spurs         False
# Toronto Raptors           False
# Utah Jazz                 False
# ...

# %%
df.groupby('Team').filter(lambda x: x['Salary'].mean()<5000000)
# Out:
#               Name                    Team  Number Position   Age    Height  \
# 0    Avery Bradley          Boston Celtics     0.0       PG  25.0  6.166667
# 1      Jae Crowder          Boston Celtics    99.0       SF  25.0  6.500000
# 3      R.J. Hunter          Boston Celtics    28.0       SG  22.0  6.416667
# 6    Jordan Mickey          Boston Celtics    55.0       PF  21.0  6.666667
# 7     Kelly Olynyk          Boston Celtics    41.0        C  25.0  7.000000
# ..             ...                     ...     ...      ...   ...       ...
# 437  C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0  6.333333
# 438   Luis Montero  Portland Trail Blazers    44.0       SG  23.0  6.583333
# 439  Mason Plumlee  Portland Trail Blazers    24.0        C  26.0  6.916667
# 440  Brian Roberts  Portland Trail Blazers     2.0       PG  30.0  6.083333
# 441    Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0  6.750000
#
#      Weight         College     Salary
# ...

# %%
df[df['Salary']<1000000]
# Out:
#                 Name                    Team  Number Position   Age    Height  \
# 16      Markel Brown           Brooklyn Nets    22.0       SG  24.0  6.250000
# 21   Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0  6.333333
# 25       Willie Reed           Brooklyn Nets    33.0       PF  26.0  6.833333
# 26   Thomas Robinson           Brooklyn Nets    41.0       PF  25.0  6.833333
# 27        Henry Sims           Brooklyn Nets    14.0        C  26.0  6.833333
# ..               ...                     ...     ...      ...   ...       ...
# 429  Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0  6.416667
# 430     Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0  6.500000
# 438     Luis Montero  Portland Trail Blazers    44.0       SG  23.0  6.583333
# 451    Chris Johnson               Utah Jazz    23.0       SF  26.0  6.500000
# 456      Jeff Withey               Utah Jazz    24.0        C  26.0  7.000000
#
# ...

# %%
import pandas as pd
df=pd.read_csv("nba (1).csv")
#Using aggregate() with a Lambda Function
#Question: Use aggregate() along with a lambda function to calculate the range (difference between max and min) of the Weight column.
df.groupby('Team').agg({'Weight': lambda x: x.max() - x.min()})
# Out:
#                         Weight
# Team
# Atlanta Hawks             88.0
# Boston Celtics            80.0
# Brooklyn Nets            100.0
# Charlotte Hornets        105.0
# Chicago Bulls            114.0
# Cleveland Cavaliers       96.0
# Dallas Mavericks          90.0
# Denver Nuggets           105.0
# Detroit Pistons          107.0
# Golden State Warriors     98.0
# Houston Rockets           80.0
# Indiana Pacers            75.0
# Los Angeles Clippers      90.0
# Los Angeles Lakers        95.0
# Memphis Grizzlies        105.0
# Miami Heat               100.0
# Milwaukee Bucks           75.0
# Minnesota Timberwolves   118.0
# New Orleans Pelicans     100.0
# New York Knicks           83.0
# Oklahoma City Thunder     70.0
# Orlando Magic             91.0
# Philadelphia 76ers       100.0
# Phoenix Suns              85.0
# Portland Trail Blazers    92.0
# Sacramento Kings          95.0
# San Antonio Spurs        105.0
# Toronto Raptors           65.0
# Utah Jazz                 86.0
# ...

# %%
display(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
'Anu-is-learning-Python'.split('-')
# Out:
# ['Anu', 'is', 'learning', 'Python']

# %%
f,i='9-6'.split('-')
type(f)
type(i)

f=int(f)
i=int(i)
#f,i
f+i
# Out:
# 15

# %%
f,i=map(int,'9-6'.split('-'))
type(f)
# Out:
# int

# %%
def cvt(a):
    f,i=map(int,a.split('-'))
    return f+i/12

# %%
df.dropna(subset=['Height'], inplace=True)

# %%
df['height']=df['Height'].apply(cvt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['Height'].apply(cvt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
cvt(df['Height'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5076\250164378.py in ?()
# ----> 1 cvt(df['Height'])
#
# ~\AppData\Local\Temp\ipykernel_5076\1695393659.py in ?(a)
#       1 def cvt(a):
# ----> 2     f,i=map(int,a.split('-'))
#       3     return f+i/12
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df['Height'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
#Question: Use the df.aggregate() function to calculate the mean, median, and standard deviation for the columns Age and Salary.
df.aggregate({'Age': ['mean', 'median', 'std'], 'Salary': ['mean', 'median', 'std']})
# Out:
#               Age        Salary
# mean    26.938731  4.842684e+06
# median  26.000000  2.839073e+06
# std      4.404016  5.229238e+06

# %%
##Question: Use the df.agg() function to calculate the mean, median, and standard deviation for the columns Age and Salary.
df.agg({'Age': ['mean', 'median', 'std'], 'Salary': ['mean', 'median', 'std']})
# Out:
#               Age        Salary
# mean    26.938731  4.842684e+06
# median  26.000000  2.839073e+06
# std      4.404016  5.229238e+06

# %%
#•	Question: Group the players by Team and calculate the mean age of players in each team using apply() and mean().
df.groupby('Team')['Age'].apply(lambda x: x.mean())
# Out:
# Team
# Atlanta Hawks             28.200000
# Boston Celtics            24.733333
# Brooklyn Nets             25.600000
# Charlotte Hornets         26.133333
# Chicago Bulls             27.400000
# Cleveland Cavaliers       29.533333
# Dallas Mavericks          29.733333
# Denver Nuggets            25.733333
# Detroit Pistons           26.200000
# Golden State Warriors     27.666667
# Houston Rockets           26.866667
# Indiana Pacers            26.400000
# Los Angeles Clippers      29.466667
# Los Angeles Lakers        27.533333
# Memphis Grizzlies         28.388889
# Miami Heat                28.933333
# Milwaukee Bucks           24.562500
# Minnesota Timberwolves    26.357143
# New Orleans Pelicans      26.894737
# New York Knicks           27.000000
# Oklahoma City Thunder     27.066667
# Orlando Magic             25.071429
# Philadelphia 76ers        24.600000
# Phoenix Suns              25.866667
# Portland Trail Blazers    25.066667
# Sacramento Kings          26.800000
# ...

# %%
salary_checker(60000)  # Example usage
# Out:
# 'High'

# %%
salary_checker(60000)  # Example usage
salary_checker(40000)  # Example usage
# Out:
# 'Low'

# %%
a=lambda x: 'High' if x>50000 else 'Low'

# %%
import pandas as pd
df=pd.read_csv("nba (1).csv")

# %%
#Group-wise Transformation:
#Normalize the 'Salary' column within each 'Position' group by subtracting the group mean and dividing by the group standard deviation.
df['Salary_Normalized'] = df.groupby('Position')['Salary'].transform(lambda x: (x - x.mean()) / x.std())

# %%
#Filter Groups Based on Aggregated Condition:
#filter out the 'Teams' where the total 'Salary' is less than 10 million.
df.groupby('Team').filter(lambda x: x['Salary'].sum() < 50000000)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 46        Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 47      Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# 48   Robert Covington      Philadelphia 76ers    33.0       SF  25.0    6-9
# 49        Joel Embiid      Philadelphia 76ers    21.0        C  22.0    7-0
# 50       Jerami Grant      Philadelphia 76ers    39.0       SF  22.0    6-8
# 51     Richaun Holmes      Philadelphia 76ers    22.0       PF  22.0   6-10
# 52        Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 53   Kendall Marshall      Philadelphia 76ers     5.0       PG  24.0    6-4
# 54     T.J. McConnell      Philadelphia 76ers    12.0       PG  24.0    6-2
# 55       Nerlens Noel      Philadelphia 76ers     4.0       PF  22.0   6-11
# 56      Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# ...

# %%
#Normalize the 'Salary' column within each 'Position' group by subtracting the group mean and dividing by the group standard deviation.
df.groupby('Position')['Salary'].transform(lambda x: (x - x.me an()) / x.std())

# %%
#create a column that ranks the players within each 'Team' based on their 'Salary' in descending order.
df['Salary_Rank'] = df.groupby('Team')['Salary'].rank(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #create a column that ranks the players within each 'Team' based on their 'Salary' in descending order.
# ----> 2 df['Salary_Rank'] = df.groupby('Team')['Salary'].rank(ascending=False)
#
# NameError: name 'df' is not defined

# %%
team_salary = df.groupby('Team')['Salary'].transform('sum')
df[team_salary<50000000]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 46        Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 47      Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# 48   Robert Covington      Philadelphia 76ers    33.0       SF  25.0    6-9
# 49        Joel Embiid      Philadelphia 76ers    21.0        C  22.0    7-0
# 50       Jerami Grant      Philadelphia 76ers    39.0       SF  22.0    6-8
# 51     Richaun Holmes      Philadelphia 76ers    22.0       PF  22.0   6-10
# 52        Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 53   Kendall Marshall      Philadelphia 76ers     5.0       PG  24.0    6-4
# 54     T.J. McConnell      Philadelphia 76ers    12.0       PG  24.0    6-2
# 55       Nerlens Noel      Philadelphia 76ers     4.0       PF  22.0   6-11
# 56      Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Salary_Normalized
# ...

# %%
df['salary_tier']= df['salary'].apply(salary_checker) 

df['salary_tier']=df['Salary'].apply(lambda x: 'High' if x>50000 else 'Low') # Apply the function to the 'salary' column

# %%
tup=[5]+[3]
tup
# Out:
# [5, 3]

# %%
t=[1]
t1=[2]
t+t1
# Out:
# [1, 2]

# %%
t=[1,2,3,4,5]
t[0],t[-1]=t[-1],t[0]
t
# Out:
# [5, 2, 3, 4, 1]

# %%
t=(1,2,3,4,5)
t=(t[-1],)+t[1:-1]+(t[0],)
t
# Out:
# (5, 2, 3, 4, 1)

# %%
set1={1,2,3,4}
set2={2,5,6,7}
set1.union(set2)
set1.intersection(set2)
set1.difference(set2)
# Out:
# {1, 3, 4}

# %%
t=(1,2,3,4,5)
li=list(t)
li
li[0],li[-1]=li[-1],li[0]
t=tuple(li)
t
# Out:
# (5, 2, 3, 4, 1)

# %%
t = (1, 2, 3, 4, 5)
t = (t[-1],) + t[1:-1] + (t[0],)
print(t)
# Out:
# (5, 2, 3, 4, 1)

# %%
t = (5, 3, 8, 2, 9)

temp = list(t)

temp[0], temp[-1] = temp[-1], temp[0]

t = tuple(temp)

print(t)
# Out:
# (9, 3, 8, 2, 5)

# %%
#	Count how many vowels are in a given string.
vowels = 'aeiouAEIOU'
count=0
for i in "I am Learning Python":
    if i in vowels:
        count =count+1
print(count)
# Out:
# 6

# %%
#Normalize the 'Salary' column within each 'Position' group by subtracting the group mean and dividing by the group standard deviation.

# %%
df---

# %%
df['Normalized_sal']=df.groupby('Position')['Salary'].transform(lambda x: (x-x.mean())/x.std())

'PG' 50000 50
'SG' 60000 10
'rg' 50000 20
'tg' 30000 30

# %%
PG ---- (2000-50000)/50
PG -----(30000-500000)/50
pg ------
Pg
sg-------(40000-60000)/10
# Out:
#   Cell In[1], line 3
#     pg ------
#              ^
# SyntaxError: invalid syntax

# %%
df.groupby('Position')['Salary'].transform(lambda x: (x - x.mean()) / x.std())
df['Salary_Normalized'] = df.groupby('Position')['Salary'].transform(lambda x: (x - x.mean()) / x.std())

# %%
#Create a column that ranks the players within each 'Team' based on their 'Salary' in descending order.
df.groupby('Team')['Salary'].rank(ascending=False)

# %%
#Find how much each player's 'Salary' deviates from the average salary of their 'Team' using transform().
df['deviation']=df.groupby('Team')['Salary'].transform(lambda x:x-x.mean())

# %%
df.groupby('Team')['Salary'].mean()

# %%
df['new_salary']=df.groupby('Team')['Salary'].transform('mean')

# %%
import pandas as pd
df=pd.read_csv("nba (1).csv")

# %%
#Filter out the 'Teams' where the total 'Salary' is less than 10 million.
df.groupby('Team').filter(lambda x: x['Salary'].sum() < 10000000)
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
#Filter out the 'Teams' that have less than 3 players.
df.groupby('Team').filter(lambda x: len(x) >= 3)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Filter out 'Positions' where the average 'Weight' is greater than 220 pounds.
df.groupby('Position').filter(lambda x: x['Weight'].mean() > 220)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 450     Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#        College      Salary
# 1    Marquette   6796117.0
# 4          NaN   5000000.0
# ...
