# %%
print("my name is John")
# Out:
# my name is John

# %%
import pandas as pd

# %%
# Data Frame, # Series

# %%
students={'Name':['Hadi','Amruthesh','Niha','Faheem','Nihal','Smitha','Anusree','Hamdan','Arnab'],'Age':[22,23,22,23,22,20,23,35,45],'Location':['Narikuni','Olavanna','Ngo kottais','Atholi','Mayanad','calicut','palakad','Thrissur','kochi']}

# %%
pd.DataFrame(students)
# Out:
#         Name  Age     Location
# 0       Hadi   22     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut
# 6    Anusree   23      palakad
# 7     Hamdan   35     Thrissur
# 8      Arnab   45        kochi

# %%
students=[['Hadi',22,'Narikuni'],['Amruthesh',23,'Olavanna'],['Niha',22,'Ngo kottais'],['Faheem',23,'Atholi'],['Nihal',22,'Mayanad'],['Smitha',20,'calicut'],['Anusree',23,'palakad'],['Hamdan',35,'Thrissur'],['Arnab',45,'kochi']]

# %%
df=pd.DataFrame(students,columns=['Name','Age','Location'])

# %%
display(df)
# Out:
#         Name  Age     Location
# 0       Hadi   21     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut
# 6    Anusree   23      palakad
# 7     Hamdan   35     Thrissur
# 8      Arnab   45        kochi

# %%
df['Marks']=[90,80,70,60,50,40,30,20,10]

# %%
display(df)
# Out:
#         Name  Age     Location
# 0       Hadi   21     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut
# 6    Anusree   23      palakad
# 7     Hamdan   35     Thrissur

# %%
df.drop('Marks',axis=1,inplace=True)

# %%
df.drop(8,inplace=True)

# %%
df
# Out:
#         Name  Age     Location
# 0       Hadi   21     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut
# 6    Anusree   23      palakad
# 7     Hamdan   35     Thrissur

# %%
df[['Name','Age']]
# Out:
#         Name  Age
# 0       Hadi   21
# 1  Amruthesh   23
# 2       Niha   22
# 3     Faheem   23
# 4      Nihal   22
# 5     Smitha   20
# 6    Anusree   23
# 7     Hamdan   35

# %%
df.loc[[1,2,7],['Name']]
# Out:
#         Name
# 1  Amruthesh
# 2       Niha
# 7     Hamdan

# %%
df.loc[0:5]
# Out:
#         Name  Age     Location
# 0       Hadi   21     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut

# %%
df.loc[[0,7,6]]
# Out:
#       Name  Age  Location
# 0     Hadi   22  Narikuni
# 7   Hamdan   35  Thrissur
# 6  Anusree   23   palakad

# %%
df.loc[[0,7,6],['Name','Age']]
# Out:
#       Name  Age
# 0     Hadi   22
# 7   Hamdan   35
# 6  Anusree   23

# %%
df.loc[0:5,'Name':'Location']
# Out:
#         Name  Age     Location
# 0       Hadi   22     Narikuni
# 1  Amruthesh   23     Olavanna
# 2       Niha   22  Ngo kottais
# 3     Faheem   23       Atholi
# 4      Nihal   22      Mayanad
# 5     Smitha   20      calicut

# %%
df.loc[0:5,['Name','Location']]
# Out:
#         Name     Location
# 0       Hadi     Narikuni
# 1  Amruthesh     Olavanna
# 2       Niha  Ngo kottais
# 3     Faheem       Atholi
# 4      Nihal      Mayanad
# 5     Smitha      calicut

# %%
df.iloc[[0,5],[0,2]]
# Out:
#      Name  Location
# 0    Hadi  Narikuni
# 5  Smitha   calicut

# %%
df.iloc[0:5,[0,2]]
# Out:
#         Name     Location
# 0       Hadi     Narikuni
# 1  Amruthesh     Olavanna
# 2       Niha  Ngo kottais
# 3     Faheem       Atholi
# 4      Nihal      Mayanad

# %%
df.iloc[0:4,0:2]
# Out:
#         Name  Age
# 0       Hadi   22
# 1  Amruthesh   23
# 2       Niha   22
# 3     Faheem   23

# %%
df.iloc[[1,2,3],0:1]
# Out:
#         Name
# 1  Amruthesh
# 2       Niha
# 3     Faheem

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#            Age     Location
# Name
# Hadi        21     Narikuni
# Amruthesh   23     Olavanna
# Niha        22  Ngo kottais
# Faheem      23       Atholi
# Nihal       22      Mayanad
# Smitha      20      calicut
# Anusree     23      palakad
# Hamdan      35     Thrissur

# %%
df.loc[['Hadi','Smitha'],['Age']]
# Out:
#         Age
# Name
# Hadi     21
# Smitha   20

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         Name  Age     Location  Mark
# 0       Hadi   21     Narikuni    10
# 1  Amruthesh   23     Olavanna    20
# 2       Niha   22  Ngo kottais    30
# 3     Faheem   23       Atholi    40
# 4      Nihal   22      Mayanad    50
# 5     Smitha   20      calicut    60
# 6    Anusree   23      palakad    70
# 7     Hamdan   35     Thrissur    80

# %%
df['Mark']=[10,20,30,40,50,60,70,80]

# %%
df['Mark']>30
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# Name: Mark, dtype: bool

# %%
(df['Age']>22) & (df['Mark']>30)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# dtype: bool

# %%
df.loc[(df['Age']>22) & (df['Mark']>30),['Name']]
# Out:
#       Name
# 3   Faheem
# 6  Anusree
# 7   Hamdan

# %%
df['Age']==22
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# Name: Age, dtype: bool

# %%
df['Marks']=[100,90,80,70,60,50,40,30]

# %%
df.loc[df['Age']==22,['Name','Age']]
# Out:
#     Name  Age
# 0   Hadi   22
# 2   Niha   22
# 4  Nihal   22

# %%
df['Marks']>=60
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# Name: Marks, dtype: bool

# %%
(df['Age']==22) & (df['Marks']>=60)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.loc[~(df['Age']==22) & (df['Marks']>=60),['Name','Age','Marks']]
# Out:
#         Name  Age  Marks
# 1  Amruthesh   23     90
# 3     Faheem   23     70

# %%
df.loc[df['Marks']>=60,['Name']]
# Out:
#         Name
# 0       Hadi
# 1  Amruthesh
# 2       Niha
# 3     Faheem
# 4      Nihal

# %%
#df.head()
df.tail(2)
# Out:
#      Name  Age  Location
# 7  Hamdan   35  Thrissur
# 8   Arnab   45     kochi

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#            Age     Location  Marks
# Name
# Hadi        22     Narikuni    100
# Amruthesh   23     Olavanna     90
# Niha        22  Ngo kottais     80
# Faheem      23       Atholi     70
# Nihal       22      Mayanad     60
# Smitha      20      calicut     50
# Anusree     23      palakad     40
# Hamdan      35     Thrissur     30

# %%
df.loc['Hadi':'Nihal']
# Out:
#            Age     Location  Marks
# Name
# Hadi        22     Narikuni    100
# Amruthesh   23     Olavanna     90
# Niha        22  Ngo kottais     80
# Faheem      23       Atholi     70
# Nihal       22      Mayanad     60

# %%
df.iloc[0:5,0:2]
# Out:
#            Age     Location
# Name
# Hadi        22     Narikuni
# Amruthesh   23     Olavanna
# Niha        22  Ngo kottais
# Faheem      23       Atholi
# Nihal       22      Mayanad

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#         Name  Age     Location  Marks
# 0       Hadi   22     Narikuni    100
# 1  Amruthesh   23     Olavanna     90
# 2       Niha   22  Ngo kottais     80
# 3     Faheem   23       Atholi     70
# 4      Nihal   22      Mayanad     60
# 5     Smitha   20      calicut     50
# 6    Anusree   23      palakad     40
# 7     Hamdan   35     Thrissur     30

# %%
df.drop('index',inplace=True,axis=1)

# %%
pd.read_csv("E:\Self-learning\Pandas\countries of the world (1).csv")
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
a=['Hadi','Amruthesh','Niha','Faheem','Nihal','Smitha','Anusree','Hamdan','Arnab']

# %%
ser1=pd.Series(a,index=[1,2,3,4,5,6,7,8,9])

# %%
#Normalize the 'Salary' column within each 'Position' group by subtracting the group mean and dividing by the group standard deviation.

# %%
pd.read_excel("E:\Self-learning\Pandas\world_population_excel_workbook.xlsx",sheet_name='Sheet1')
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El Aai̼n
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
display(ser1)
# Out:
# 1         Hadi
# 2    Amruthesh
# 3         Niha
# 4       Faheem
# 5        Nihal
# 6       Smitha
# 7      Anusree
# 8       Hamdan
# 9        Arnab
# dtype: object

# %%
a=['Hadi','Amruthesh','Niha','Faheem','Nihal','Smitha','Anusree','Hamdan','Arnab']
ser1=pd.Series(a,index=[1,2,3,4,5,6,7,8,9])
display(ser1)
print("Nihala")
print(1)
{'a':1,'b':2}
# Out:
# 1         Hadi
# 2    Amruthesh
# 3         Niha
# 4       Faheem
# 5        Nihal
# 6       Smitha
# 7      Anusree
# 8       Hamdan
# 9        Arnab
# dtype: object
# Nihala
# 1
# {'a': 1, 'b': 2}

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Age': [24, 22, 23, 25, 21, 24],
    'Marks': [85, 92, 78, 88, 90, 75],
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M'],
    'Passed': [True, True, False, True, True, False]
}

df=pd.DataFrame(data)

display(df)
# Out:
#       Name  Age  Marks Gender  Passed
# 0    Alice   24     85      F    True
# 1      Bob   22     92      M    True
# 2  Charlie   23     78      M   False
# 3    David   25     88      M    True
# 4      Eva   21     90      F    True
# 5    Frank   24     75      M   False

# %%
def perc(a):
    return a/100*100

# %%
perc(92)
# Out:
# 92.0

# %%
df['perc']=perc(df['Marks'])

# %%
df['Marks'].apply(perc)
# Out:
# 0    85.0
# 1    92.0
# 2    78.0
# 3    88.0
# 4    90.0
# 5    75.0
# Name: Marks, dtype: float64

# %%
df['age_level']=df['Age'].apply(age_checker)

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed  Percentage  perc age_level
# 0    Alice   24     85      F    True        85.0  85.0     adult
# 1      Bob   22     92      M    True        92.0  92.0     Young
# 2  Charlie   23     78      M   False        78.0  78.0     Young
# 3    David   25     88      M    True        88.0  88.0     adult
# 4      Eva   21     90      F    True        90.0  90.0     Young
# 5    Frank   24     75      M   False        75.0  75.0     adult

# %%
#Add a new column called Result that stores "Pass" if Passed == True, otherwise "Fail".
def pass1(a):
   if a==True:
      return 'pass'
   else:
      return 'fail'

# %%
pass1('False')
# Out:
# 'fail'

# %%
df['result']=df['Passed'].apply(pass1)

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed  Percentage  perc age_level result
# 0    Alice   24     85      F    True        85.0  85.0     adult   pass
# 1      Bob   22     92      M    True        92.0  92.0     Young   pass
# 2  Charlie   23     78      M   False        78.0  78.0     Young   fail
# 3    David   25     88      M    True        88.0  88.0     adult   pass
# 4      Eva   21     90      F    True        90.0  90.0     Young   pass
# 5    Frank   24     75      M   False        75.0  75.0     adult   fail

# %%
df.loc[[5]]
# Out:
#     Name  Age  Marks Gender  Passed  Percentage  perc age_level result
# 5  Frank   24     75      M   False        75.0  75.0     adult   fail

# %%
df.loc[len(df)]=['Grace',23,85,'F',True,85.0,85.0,'young','Pass']

# %%
len(df)
# Out:
# 7

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed  Percentage  perc age_level result
# 0    Alice   24     85      F    True        85.0  85.0     adult   pass
# 1      Bob   22     92      M    True        92.0  92.0     Young   pass
# 2  Charlie   23     78      M   False        78.0  78.0     Young   fail
# 3    David   25     88      M    True        88.0  88.0     adult   pass
# 4      Eva   21     90      F    True        90.0  90.0     Young   pass
# 5    Frank   24     75      M   False        75.0  75.0     adult   fail
# 6    Grace   23     85      F    True        85.0  85.0     young   Pass

# %%
def age_checker(a):
    if a<=23:
        return 'Young'
    else:
        return 'adult'

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed  Percentage  perc
# 0    Alice   24     85      F    True        85.0  85.0
# 1      Bob   22     92      M    True        92.0  92.0
# 2  Charlie   23     78      M   False        78.0  78.0
# 3    David   25     88      M    True        88.0  88.0
# 4      Eva   21     90      F    True        90.0  90.0
# 5    Frank   24     75      M   False        75.0  75.0

# %%
df['Percentage']= df['Marks'] / 100 * 100

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed  Percentage
# 0    Alice   24     85      F    True        85.0
# 1      Bob   22     92      M    True        92.0
# 2  Charlie   23     78      M   False        78.0
# 3    David   25     88      M    True        88.0
# 4      Eva   21     90      F    True        90.0
# 5    Frank   24     75      M   False        75.0
