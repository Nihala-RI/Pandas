# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\Self-learning\Pandas\world_population (1).csv")

# %%
display(df)
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.iloc[0:5,0:3]  # First 5 rows and first 3 columns
# Out:
#    Rank CCA3         Country
# 0    36  AFG     Afghanistan
# 1   138  ALB         Albania
# 2    34  DZA         Algeria
# 3   213  ASM  American Samoa
# 4   203  AND         Andorra

# %%
df.loc[0:50,'Rank':'Country']  # First 50 rows and columns from 'Country' to 'Population'
# Out:
#     Rank CCA3                   Country
# 0     36  AFG               Afghanistan
# 1    138  ALB                   Albania
# 2     34  DZA                   Algeria
# 3    213  ASM            American Samoa
# 4    203  AND                   Andorra
# 5     42  AGO                    Angola
# 6    224  AIA                  Anguilla
# 7    201  ATG       Antigua and Barbuda
# 8     33  ARG                 Argentina
# 9    140  ARM                   Armenia
# 10   198  ABW                     Aruba
# 11    55  AUS                 Australia
# 12    99  AUT                   Austria
# 13    91  AZE                Azerbaijan
# 14   176  BHS                   Bahamas
# 15   154  BHR                   Bahrain
# 16     8  BGD                Bangladesh
# 17   186  BRB                  Barbados
# 18    96  BLR                   Belarus
# 19    81  BEL                   Belgium
# 20   177  BLZ                    Belize
# 21    77  BEN                     Benin
# ...

# %%
df['Rank']<=50
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231     True
# 232    False
# 233    False
# Name: Rank, Length: 234, dtype: bool

# %%
(df['Continent']=='Asia') & (df['Rank']<=50) # Countries in Asia with Rank <= 50
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231     True
# 232    False
# 233    False
# Length: 234, dtype: bool

# %%
df.loc[(df['Continent']=='Asia') & (df['Rank']<=50),['Rank','Country','Capital','Continent']]
# Out:
#      Rank       Country       Capital Continent
# 0      36   Afghanistan         Kabul      Asia
# 16      8    Bangladesh         Dhaka      Asia
# 41      1         China       Beijing      Asia
# 92      2         India     New Delhi      Asia
# 93      4     Indonesia       Jakarta      Asia
# 94     17          Iran        Tehran      Asia
# 95     35          Iraq       Baghdad      Asia
# 102    11         Japan         Tokyo      Asia
# 122    45      Malaysia  Kuala Lumpur      Asia
# 140    26       Myanmar   Nay Pyi Taw      Asia
# 143    49         Nepal     Kathmandu      Asia
# 156     5      Pakistan     Islamabad      Asia
# 163    13   Philippines        Manila      Asia
# 182    41  Saudi Arabia        Riyadh      Asia
# 194    29   South Korea         Seoul      Asia
# 206    20      Thailand       Bangkok      Asia
# 213    18        Turkey        Ankara      Asia
# 224    43    Uzbekistan      Tashkent      Asia
# 228    16       Vietnam         Hanoi      Asia
# ...

# %%
0,2,5,8,26,27,41

# %%
df["Rank"]==36
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: Rank, Length: 234, dtype: bool

# %%
df.loc[df["Rank"]==36,["Country","Rank"]]
# Out:
#        Country  Rank
# 0  Afghanistan    36

# %%
df[(df['Rank']<=10) & (df['Country'].str.contains('United'))]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 221      338289857.0      335942003.0      324607776.0      311182845.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 221      282398554.0      248083732.0      223140018.0      200328340.0
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 221   9372610.0            36.0935       1.0038                         4.24

# %%
df.loc[(df['Country']=='Bangladesh') | (df['Rank']==5)]
# Out:
#      Rank CCA3     Country    Capital Continent  2022 Population  \
# 16      8  BGD  Bangladesh      Dhaka      Asia      171186372.0
# 156     5  PAK    Pakistan  Islamabad      Asia      235824862.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 16       167420951.0      157830000.0      148391139.0      129193327.0
# 156      227196741.0      210969298.0      194454498.0      154369924.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16       107147651.0       83929765.0       67541860.0    147570.0
# 156      115414069.0       80624057.0       59290872.0    881912.0
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 16           1160.0350       1.0108                         2.15
# 156           267.4018       1.0191                         2.96

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Age': [24, 22, 23, 25, 21, 24],
    'Marks': [85, 92, 78, 88, 90, 75],
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M'],
    'Passed': [True, True, False, True, True, False]
}

df=pd.DataFrame(data)
df
# Out:
#       Name  Age  Marks Gender  Passed
# 0    Alice   24     85      F    True
# 1      Bob   22     92      M    True
# 2  Charlie   23     78      M   False
# 3    David   25     88      M    True
# 4      Eva   21     90      F    True
# 5    Frank   24     75      M   False

# %%
df['Grades']=['A', 'A+', 'B', 'B+', 'A', 'C']  # Adding a new column with grades

# %%
pd.Series(['A', 'A+', 'B', 'B+', 'A', 'C'], index=[0, 1, 2, 3, 4, 5])
# Out:
# 0     A
# 1    A+
# 2     B
# 3    B+
# 4     A
# 5     C
# dtype: object

# %%
df['Grades']=pd.Series(['A', 'A+', 'B', 'B+', 'A', 'C'], index=df.index)

# %%
df
# Out:
#       Name  Age  Marks Gender  Passed Grades
# 0    Alice   24     85      F    True      A
# 1      Bob   22     92      M    True     A+
# 2  Charlie   23     78      M   False      B
# 3    David   25     88      M    True     B+
# 4      Eva   21     90      F    True      A
# 5    Frank   24     75      M   False      C

# %%
df.loc[(df['Country'] == 'Bangladesh') & ~(df['Rank'] == 5)]
# Out:
#     Rank CCA3     Country Capital Continent  2022 Population  2020 Population  \
# 16     8  BGD  Bangladesh   Dhaka      Asia      171186372.0      167420951.0
#
#     2015 Population  2010 Population  2000 Population  1990 Population  \
# 16      157830000.0      148391139.0      129193327.0      107147651.0
#
#     1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 16       83929765.0       67541860.0    147570.0           1160.035
#
#     Growth Rate  World Population Percentage
# 16       1.0108                         2.15

# %%
specific_countries = ['Bangladesh','Brazil']

df[df['Country'].isin(specific_countries)]

df.loc[(df['Country']=='Bangladesh')| (df['Country']=='Brazil')]
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia      171186372.0
# 27     7  BRA      Brazil  Brasilia  South America      215313498.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      167420951.0      157830000.0      148391139.0      129193327.0
# 27      213196304.0      205188205.0      196353492.0      175873720.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16      107147651.0       83929765.0       67541860.0    147570.0
# 27      150706446.0      122288383.0       96369875.0   8515767.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df2[['Capital','Continent']]
#df2[['Capital']]
# Out:
#                             Capital Continent
# Country
# Afghanistan                   Kabul      Asia
# Albania                      Tirana    Europe
# Algeria                     Algiers    Africa
# American Samoa            Pago Pago   Oceania
# Andorra            Andorra la Vella    Europe
# ...                             ...       ...
# Wallis and Futuna          Mata-Utu   Oceania
# Western Sahara             El Aaiún    Africa
# Yemen                         Sanaa      Asia
# Zambia                       Lusaka    Africa
# Zimbabwe                     Harare    Africa
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Continent','CCA3'], axis = 1)
# Out:
#                   Continent CCA3
# Country
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Zimbabwe'], axis = 0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Country
# Zimbabwe    74  ZWE  Harare    Africa       16320537.0       15669666.0
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# Zimbabwe       14154937.0       12839771.0       11834676.0       10113893.0
#
#           1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# Zimbabwe        7049926.0        5202918.0    390757.0            41.7665
#
#           Growth Rate  World Population Percentage
# Country
# Zimbabwe       1.0204                          0.2

# %%
df2.filter(like = 'United', axis = 0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                9441129.0        9287289.0
# United Kingdom                     67508936.0       67059474.0
# United States                     338289857.0      335942003.0
# United States Virgin Islands          99465.0         100442.0
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                8916899.0        8481771.0
# United Kingdom                     65224364.0       62760039.0
# ...

# %%
df2.loc[['United States']]
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# United States     3  USA  Washington, D.C.  North America      338289857.0
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# United States      335942003.0      324607776.0      311182845.0
#
#                2000 Population  1990 Population  1980 Population  \
# Country
# United States      282398554.0      248083732.0      223140018.0
#
#                1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Country
# United States      200328340.0   9372610.0            36.0935       1.0038
#
#                World Population Percentage
# Country
# United States                         4.24

# %%
df2.iloc[[221]]
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# Country
# United States     3  USA  Washington, D.C.  North America      338289857.0
#
#                2020 Population  2015 Population  2010 Population  \
# Country
# United States      335942003.0      324607776.0      311182845.0
#
#                2000 Population  1990 Population  1980 Population  \
# Country
# United States      282398554.0      248083732.0      223140018.0
#
#                1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Country
# United States      200328340.0   9372610.0            36.0935       1.0038
#
#                World Population Percentage
# Country
# United States                         4.24

# %%
df2.sort_values(by='Rank')
# Out:
#                   Rank CCA3           Capital      Continent  2022 Population  \
# Country
# China                1  CHN           Beijing           Asia     1.425887e+09
# India                2  IND         New Delhi           Asia     1.417173e+09
# United States        3  USA  Washington, D.C.  North America     3.382899e+08
# Indonesia            4  IDN           Jakarta           Asia     2.755013e+08
# Pakistan             5  PAK         Islamabad           Asia     2.358249e+08
# ...                ...  ...               ...            ...              ...
# Montserrat         230  MSR            Brades  North America     4.390000e+03
# Falkland Islands   231  FLK           Stanley  South America     3.780000e+03
# Niue               232  NIU             Alofi        Oceania     1.934000e+03
# Tokelau            233  TKL          Nukunonu        Oceania     1.871000e+03
# Vatican City       234  VAT      Vatican City         Europe     5.100000e+02
#
# ...

# %%
df[df['Rank'] < 10].sort_values(by='Continent',ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %%
df[df['Rank'] < 10].sort_values(by=['Continent',"Rank"])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df[df['Rank'] < 10].sort_values(by=['Continent',"Rank"],ascending=[True,False])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 156     2.358249e+08     2.271967e+08     2.109693e+08     1.944545e+08
# ...
